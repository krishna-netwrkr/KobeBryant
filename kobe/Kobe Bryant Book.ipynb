# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from scipy.stats import linregress

df= pd.read_csv('kobepergame.csv', index_col=0)

# %%
# from seaborn libraray
df= pd.read_csv('kobepergame.csv')

#set chart
sns.barplot(x = 'Season',
            y = 'PTS',
            data = df,
            palette="Blues_d")
 
# rote x-labels
plt.xticks(rotation=-45)

#show plot
plt. show()

# %%
df=pd.read_csv('kobepergame.csv')
sns.lmplot(x='FGA', y='PTS', data=df)
df1=pd.read_csv('kobeplayoffavg.csv')
sns.lmplot(x='FGA', y='PTS', data=df1)data:image/png;base64,...
plt.show()

# %%
ax = sns.violinplot(x="Season", y="PTS", data=df)

# %%
df.head()
# Out:
#     Season   Age   Tm   Lg Pos   G  GS    MP    FG   FGA  ...    FT%  ORB  \
# 0  1996-97  18.0  LAL  NBA  SF  71   6  15.5   2.5   5.9  ...  0.819  0.7
# 1  1997-98  19.0  LAL  NBA  SF  79   1  26.0   4.9  11.6  ...  0.794  1.0
# 2  1998-99  20.0  LAL  NBA  SG  50  50  37.9   7.2  15.6  ...  0.839  1.1
# 3  1999-00  21.0  LAL  NBA  SG  66  62  38.2   8.4  17.9  ...  0.821  1.6
# 4  2000-01  22.0  LAL  NBA  SG  68  68  40.9  10.3  22.2  ...  0.853  1.5
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  1.2  1.9  1.3  0.7  0.3  1.6  1.4   7.6
# 1  2.1  3.1  2.5  0.9  0.5  2.0  2.3  15.4
# 2  4.2  5.3  3.8  1.4  1.0  3.1  3.1  19.9
# 3  4.7  6.3  4.9  1.6  0.9  2.8  3.3  22.5
# 4  4.3  5.9  5.0  1.7  0.6  3.2  3.3  28.5
#
# [5 rows x 30 columns]

# %%
stats_df = df.drop(['Lg', 'Tm','G', 'GS'], axis=1)

sns.boxplot(data=stats_df)
plt.show()

# %%
# from seaborn libraraypri
df= pd.read_csv('shooting.csv')
print(df)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0      Season        Age         Tm         Lg        Pos          G
# 1     1996-97         18        LAL        NBA         SF         71
# 2     1997-98         19        LAL        NBA         SF         79
# 3     1998-99         20        LAL        NBA         SG         50
# 4     1999-00         21        LAL        NBA         SG         66
# 5     2000-01         22        LAL        NBA         SG         68
# 6     2001-02         23        LAL        NBA         SG         80
# 7     2002-03         24        LAL        NBA         SG         82
# 8     2003-04         25        LAL        NBA         SG         65
# 9     2004-05         26        LAL        NBA         SG         66
# 10    2005-06         27        LAL        NBA         SG         80
# 11    2006-07         28        LAL        NBA         SG         77
# 12    2007-08         29        LAL        NBA         SG         82
# ...

# %%
#set chart
sns.barplot(x = 'Season',
            y = 'PTS',
            data = df,
            palette="Blues_d")
 
# rote x-labels
plt.xticks(rotation=-45)

#show plot
plt. show()

# %%
 
# Violin plot
sns.violinplot(x='Season', y='PTS', data=df)
plt.xticks(rotation=-45)

plt.show()
